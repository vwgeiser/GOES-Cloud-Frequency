# %%
import os
import glob
import xarray as xr
import pandas as pd
import numpy as np
from rasterio.mask import mask
from datetime import datetime, timedelta
from tqdm import tqdm
import matplotlib.pyplot as plt
import rioxarray
import rasterio as rasterio
from pyproj import CRS

# %%
# Read the data directory
# cm_dir = r"D:\GOES_data_CM\2022"

# CHANGE YEAR HERE

cm_dir = r"D:\GOES_data_CM\2023"

# %%
# Find all NetCDF files in the directory
day_paths = glob.glob(os.path.join(cm_dir, '*'),recursive=True)
# day_paths

# %%
# lat_lon_nc = xr.open_dataset(r"D:\goes16_abi_conus_lat_lon\goes16_abi_conus_lat_lon.nc")
# transposed_data = lat_lon_nc.transpose('columns', 'rows')
# goes_16_lat = transposed_data['latitude']
# goes_16_lon = transposed_data['longitude']
# goes_16_lat

# %%
def nan_to_mask(array):
    """
    Convert NaN values in an array to a mask.

    Parameters:
    array (ndarray): Input array with NaN values.

    Returns:
    ndarray: Mask array where NaN values are replaced with 0 and non-NaN values with 1.
    """
    mask = np.isnan(array)
    return (~mask).astype(int)

# %%
# Keep track of yearly total coverage
yearly_total_coverage = None

# For each day within goes2go download file structure
for day in day_paths:
    # Get all scans for every day
    day_nc_files_every_scan = glob.glob(day + '/*/*.nc')

    # Get the current day for final file name (example: '001' or '272') depending on day
    day_string = str(day_nc_files_every_scan[0]).split('\\')[3] 

    daily_max_scans = len(day_nc_files_every_scan)
    print('Max scans for ' + str(day_string) + ' is ' + str(daily_max_scans))

    # Initialize containers for summed data and coverage frequency
    summed_data = None
    coverage_frequency = None

    badlist =[]
    
    ## Main aggregation loop
    # For every scan in a day
    for scan in day_nc_files_every_scan:
        # Open the .nc file using xarray
        with xr.open_dataset(scan) as ds:
            # print(str(scan) + " contains nan values")
            # print(np.isnan(ds.BCM.values).any())
            if np.count_nonzero(np.isnan(ds.BCM.values)) > 47162: #np.isnan(ds.BCM.values).any(): # If the scan contains missing data
                # print("DEBUG num nans is = ")
                # print(str(np.count_nonzero(np.isnan(ds.BCM.values))))
                print("scan " + str(scan) + " was skipped due to incomplete scan")
                badlist = badlist.append(scan)
                # x = ds.BCM.values
                # continue
                if coverage_frequency is None:
                    coverage_frequency = nan_to_mask(ds.BCM.values)
                else:
                    # Get the locations of the good data
                    coverage_frequency += nan_to_mask(ds.BCM.values)

                # good_data_mask = nan_to_mask(ds.BCM.values)

                # # Add BCM values for the current .nc file to summed_data
                # if summed_data is None:
                #     # Initialize summed_data if it hasn't been initialized yet
                #     summed_data = ds.BCM.values * good_data_mask
                # else:
                #     # Add BCM values to summed_data
                #     summed_data += ds.BCM.values * good_data_mask           
            else: # If the scan is complete (i.e. has data for every pixel)
                if coverage_frequency is None:
                    # a += b
                    # np.add(a, b, out=a, casting="unsafe")
                    coverage_frequency = np.ones_like(ds.BCM.values)
                else:
                    np.add(coverage_frequency, np.ones_like(ds.BCM.values), out=coverage_frequency, casting="unsafe")
                    # coverage_frequency += np.ones_like(ds.BCM.values)

                if summed_data is None:
                    # Initialize summed_data if it hasn't been initialized yet
                    summed_data = ds.BCM.values
                else:
                    # Add BCM values to summed_data
                    summed_data += ds.BCM.values
        
    # Calculate the true cloud frequency accounting for missing data
    final_cloud_frequency = summed_data / coverage_frequency

    # Obtain the satellite height from the last scan in the day
    sat_height = ds.goes_imager_projection.attrs["perspective_point_height"]
    # Create a pyproj CRS
    cc = CRS.from_cf(ds.goes_imager_projection.attrs)

    # changed from summed_data
    # summed_dataset = xr.Dataset({'DCF': (('y', 'x'), final_cloud_frequency)},
    #                         coords={'x': ds.x.values * sat_height, 'y': ds.y.values * sat_height})
    summed_dataset = xr.Dataset({'Cloud_Frequency': (('y', 'x'), summed_data)},
                            coords={'x': ds.x.values * sat_height, 'y': ds.y.values * sat_height})

    summed_dataset.rio.write_crs(cc.to_string(), inplace=True)

    day_final = summed_dataset.rio.reproject("EPSG:3857") #9822

    # Save the aggregated data to a new NetCDF file
    day_final.to_netcdf('D:/GOES_CF_NCs/2022' + day_string + '.nc') # Summed_dataset


    # Calculate yearly coverage data
    if yearly_total_coverage is None:
        yearly_total_coverage = coverage_frequency
    else:
        yearly_total_coverage += coverage_frequency

    # Time to run for a full year: 215 Minutes (~4 hours)
# Out:
# Max scans for 001 is 288
# Max scans for 002 is 288
# Max scans for 003 is 288
# Max scans for 004 is 288
# Max scans for 005 is 288
# Max scans for 006 is 288
# Max scans for 007 is 288
# Max scans for 008 is 288
# Max scans for 009 is 288
# Max scans for 010 is 288
# Max scans for 011 is 288
# Max scans for 012 is 288
# Max scans for 013 is 288
# Max scans for 014 is 288
# Max scans for 015 is 288
# Max scans for 016 is 288
# Max scans for 017 is 288
# Max scans for 018 is 288
# Max scans for 019 is 288
# Max scans for 020 is 288
# Max scans for 021 is 288
# Max scans for 022 is 288
# Max scans for 023 is 288
# Max scans for 024 is 288
# Max scans for 025 is 288
# Max scans for 026 is 288
# Max scans for 027 is 288
# Max scans for 028 is 288
# Max scans for 029 is 288
# Max scans for 030 is 288
# Max scans for 031 is 288
# Max scans for 032 is 288
# Max scans for 033 is 288
# Max scans for 034 is 288
# Max scans for 035 is 287
# scan D:\GOES_data_CM\2023\035\11\OR_ABI-L2-ACMC-M4_G16_s20230351115223_e20230351115223_c20230351122339.nc was skipped due to incomplete scan
# Max scans for 036 is 288
# Max scans for 037 is 288
# Max scans for 038 is 288
# Max scans for 039 is 288
# Max scans for 040 is 288
# Max scans for 041 is 288
# Max scans for 042 is 288
# Max scans for 043 is 288
# Max scans for 044 is 288
# scan D:\GOES_data_CM\2023\044\06\OR_ABI-L2-ACMC-M6_G16_s20230440646174_e20230440648547_c20230440649377.nc was skipped due to incomplete scan
# Max scans for 045 is 288
# Max scans for 046 is 288
# Max scans for 047 is 288
# Max scans for 048 is 288
# Max scans for 049 is 287
# scan D:\GOES_data_CM\2023\049\11\OR_ABI-L2-ACMC-M4_G16_s20230491115224_e20230491115224_c20230491122351.nc was skipped due to incomplete scan
# Max scans for 050 is 288
# Max scans for 051 is 288
# Max scans for 052 is 288
# Max scans for 053 is 288
# Max scans for 054 is 288
# Max scans for 055 is 288
# Max scans for 056 is 288
# Max scans for 057 is 288
# Max scans for 058 is 288
# Max scans for 059 is 288
# Max scans for 060 is 288
# scan D:\GOES_data_CM\2023\060\07\OR_ABI-L2-ACMC-M6_G16_s20230600746174_e20230600748547_c20230600749546.nc was skipped due to incomplete scan
# Max scans for 061 is 288
# Max scans for 062 is 286
# Max scans for 063 is 286
# scan D:\GOES_data_CM\2023\063\07\OR_ABI-L2-ACMC-M6_G16_s20230630731176_e20230630733549_c20230630735015.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\063\17\OR_ABI-L2-ACMC-M6_G16_s20230631706170_e20230631706170_c20230631714529.nc was skipped due to incomplete scan
# Max scans for 064 is 287
# scan D:\GOES_data_CM\2023\064\17\OR_ABI-L2-ACMC-M6_G16_s20230641706170_e20230641706170_c20230641716220.nc was skipped due to incomplete scan
# Max scans for 065 is 287
# scan D:\GOES_data_CM\2023\065\17\OR_ABI-L2-ACMC-M6_G16_s20230651706171_e20230651706171_c20230651714584.nc was skipped due to incomplete scan
# Max scans for 066 is 288
# Max scans for 067 is 278
# Max scans for 068 is 288
# Max scans for 069 is 288
# Max scans for 070 is 288
# scan D:\GOES_data_CM\2023\070\07\OR_ABI-L2-ACMC-M6_G16_s20230700736172_e20230700738545_c20230700739542.nc was skipped due to incomplete scan
# Max scans for 071 is 288
# Max scans for 072 is 288
# Max scans for 073 is 288
# scan D:\GOES_data_CM\2023\073\16\OR_ABI-L2-ACMC-M6_G16_s20230731651173_e20230731653546_c20230731655059.nc was skipped due to incomplete scan
# Max scans for 074 is 288
# Max scans for 075 is 288
# Max scans for 076 is 288
# Max scans for 077 is 286
# Max scans for 078 is 288
# Max scans for 079 is 279
# Max scans for 080 is 288
# Max scans for 081 is 288
# scan D:\GOES_data_CM\2023\081\04\OR_ABI-L2-ACMC-M6_G16_s20230810436164_e20230810438537_c20230810439565.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\081\22\OR_ABI-L2-ACMC-M6_G16_s20230812206165_e20230812208538_c20230812210130.nc was skipped due to incomplete scan
# Max scans for 082 is 288
# scan D:\GOES_data_CM\2023\082\04\OR_ABI-L2-ACMC-M6_G16_s20230820436165_e20230820438538_c20230820440085.nc was skipped due to incomplete scan
# Max scans for 083 is 288
# scan D:\GOES_data_CM\2023\083\04\OR_ABI-L2-ACMC-M6_G16_s20230830431165_e20230830433538_c20230830434505.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\083\04\OR_ABI-L2-ACMC-M6_G16_s20230830436165_e20230830438539_c20230830439417.nc was skipped due to incomplete scan
# Max scans for 084 is 288
# scan D:\GOES_data_CM\2023\084\04\OR_ABI-L2-ACMC-M6_G16_s20230840431166_e20230840433541_c20230840434530.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\084\04\OR_ABI-L2-ACMC-M6_G16_s20230840436166_e20230840438543_c20230840439456.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\084\07\OR_ABI-L2-ACMC-M6_G16_s20230840736166_e20230840738539_c20230840745429.nc was skipped due to incomplete scan
# Max scans for 085 is 288
# scan D:\GOES_data_CM\2023\085\04\OR_ABI-L2-ACMC-M6_G16_s20230850431166_e20230850433539_c20230850434494.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\085\04\OR_ABI-L2-ACMC-M6_G16_s20230850436166_e20230850438541_c20230850439383.nc was skipped due to incomplete scan
# Max scans for 086 is 288
# scan D:\GOES_data_CM\2023\086\04\OR_ABI-L2-ACMC-M6_G16_s20230860431166_e20230860433542_c20230860434489.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023
nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\135\20\OR_ABI-L2-ACMC-M6_G16_s20231352011171_e20231352013544_c20231352015491.nc was skipped due to incomplete scan
# Max scans for 136 is 288
# scan D:\GOES_data_CM\2023\136\02\OR_ABI-L2-ACMC-M6_G16_s20231360216171_e20231360218544_c20231360219512.nc was skipped due to incomplete scan
# Max scans for 137 is 288
# scan D:\GOES_data_CM\2023\137\11\OR_ABI-L2-ACMC-M6_G16_s20231371146171_e20231371148544_c20231371149523.nc was skipped due to incomplete scan
# Max scans for 138 is 288
# scan D:\GOES_data_CM\2023\138\20\OR_ABI-L2-ACMC-M6_G16_s20231382006172_e20231382008545_c20231382009526.nc was skipped due to incomplete scan
# Max scans for 139 is 288
# scan D:\GOES_data_CM\2023\139\13\OR_ABI-L2-ACMC-M6_G16_s20231391341172_e20231391343545_c20231391344487.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\139\13\OR_ABI-L2-ACMC-M6_G16_s20231391351172_e20231391353545_c20231391354529.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\139\18\OR_ABI-L2-ACMC-M6_G16_s20231391846173_e20231391848546_c20231391849536.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\139\18\OR_ABI-L2-ACMC-M6_G16_s20231391851173_e20231391853546_c20231391854528.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\139\21\OR_ABI-L2-ACMC-M6_G16_s20231392106173_e20231392108546_c20231392109491.nc was skipped due to incomplete scan
# Max scans for 140 is 288
# scan D:\GOES_data_CM\2023\140\21\OR_ABI-L2-ACMC-M6_G16_s20231402116173_e20231402118546_c20231402119515.nc was skipped due to incomplete scan
# Max scans for 141 is 288
# scan D:\GOES_data_CM\2023\141\00\OR_ABI-L2-ACMC-M6_G16_s20231410026173_e20231410028546_c20231410029526.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\141\13\OR_ABI-L2-ACMC-M6_G16_s20231411306174_e20231411308546_c20231411309507.nc was skipped due to incomplete scan
# Max scans for 142 is 288
# scan D:\GOES_data_CM\2023\142\05\OR_ABI-L2-ACMC-M6_G16_s20231420521174_e20231420523547_c20231420524522.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\142\18\OR_ABI-L2-ACMC-M6_G16_s20231421801174_e20231421803547_c20231421804494.nc was skipped due to incomplete scan
# Max scans for 143 is 286
# scan D:\GOES_data_CM\2023\143\00\OR_ABI-L2-ACMC-M6_G16_s20231430001174_e20231430003547_c20231430004530.nc was skipped due to incomplete scan
# Max scans for 144 is 288
# Max scans for 145 is 288
# Max scans for 146 is 288
# scan D:\GOES_data_CM\2023\146\18\OR_ABI-L2-ACMC-M6_G16_s20231461841171_e20231461843544_c20231461844532.nc was skipped due to incomplete scan
# Max scans for 147 is 288
# Max scans for 148 is 288
# Max scans for 149 is 288
# Max scans for 150 is 284
# scan D:\GOES_data_CM\2023\150\19\OR_ABI-L2-ACMC-M6_G16_s20231501916173_e20231501918546_c20231501921197.nc was skipped due to incomplete scan
# Max scans for 151 is 288
# Max scans for 152 is 288
# Max scans for 153 is 287
# Max scans for 154 is 288
# Max scans for 155 is 288
# Max scans for 156 is 288
# Max scans for 157 is 288
# Max scans for 158 is 288
# Max scans for 159 is 288
# Max scans for 160 is 288
# Max scans for 161 is 288
# scan D:\GOES_data_CM\2023\161\11\OR_ABI-L2-ACMC-M4_G16_s20231611100219_e20231611100219_c20231611106421.nc was skipped due to incomplete scan
# Max scans for 162 is 288
# Max scans for 163 is 288
# scan D:\GOES_data_CM\2023\163\05\OR_ABI-L2-ACMC-M6_G16_s20231630526172_e20231630528545_c20231630529558.nc was skipped due to incomplete scan
# Max scans for 164 is 288
# Max scans for 165 is 288
# Max scans for 166 is 288
# Max scans for 167 is 287
# Max scans for 168 is 286
# scan D:\GOES_data_CM\2023\168\08\OR_ABI-L2-ACMC-M6_G16_s20231680821179_e20231680823552_c20231680825484.nc was skipped due to incomplete scan
# Max scans for 169 is 288
# Max scans for 170 is 288
# Max scans for 171 is 286
# scan D:\GOES_data_CM\2023\171\16\OR_ABI-L2-ACMC-M6_G16_s20231711636183_e20231711638556_c20231711640295.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\171\19\OR_ABI-L2-ACMC-M6_G16_s20231711921184_e20231711923557_c20231711924246.nc was skipped due to incomplete scan
# Max scans for 172 is 288
# scan D:\GOES_data_CM\2023\172\02\OR_ABI-L2-ACMC-M6_G16_s20231720236184_e20231720238557_c20231720239576.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\172\17\OR_ABI-L2-ACMC-M6_G16_s20231721741185_e20231721743558_c20231721746489.nc was skipped due to incomplete scan
# Max scans for 173 is 288
# scan D:\GOES_data_CM\2023\173\09\OR_ABI-L2-ACMC-M6_G16_s20231730931186_e20231730933559_c20231730934568.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\173\17\OR_ABI-L2-ACMC-M6_G16_s20231731716186_e20231731718559_c20231731720122.nc was skipped due to incomplete scan
# Max scans for 174 is 286
# scan D:\GOES_data_CM\2023\174\12\OR_ABI-L2-ACMC-M6_G16_s20231741241187_e20231741243560_c20231741245023.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\174\19\OR_ABI-L2-ACMC-M6_G16_s20231741936188_e20231741938561_c20231741941138.nc was skipped due to incomplete scan
# Max scans for 175 is 287
# Max scans for 176 is 288
# Max scans for 177 is 287
# scan D:\GOES_data_CM\2023\177\02\OR_ABI-L2-ACMC-M6_G16_s20231770211172_e20231770213545_c20231770215002.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\177\11\OR_ABI-L2-ACMC-M6_G16_s20231771156172_e20231771158545_c20231771159569.nc was skipped due to incomplete scan
# Max scans for 178 is 287
# scan D:\GOES_data_CM\2023\178\02\OR_ABI-L2-ACMC-M6_G16_s20231780236173_e20231780238546_c20231780239498.nc was skipped due to incomplete scan
# Max scans for 179 is 288
# scan D:\GOES_data_CM\2023\179\15\OR_ABI-L2-ACMC-M6_G16_s20231791516175_e20231791518548_c20231791519494.nc was skipped due to incomplete scan
# Max scans for 180 is 288
# Max scans for 181 is 288
# Max scans for 182 is 288
# scan D:\GOES_data_CM\2023\182\01\OR_ABI-L2-ACMC-M6_G16_s20231820141179_e20231820143552_c20231820144513.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\182\07\OR_ABI-L2-ACMC-M6_G16_s20231820706179_e20231820708552_c20231820709516.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\182\18\OR_ABI-L2-ACMC-M6_G16_s20231821836180_e20231821838552_c20231821839479.nc was skipped due to incomplete scan
# Max scans for 183 is 288
# scan D:\GOES_data_CM\2023\183\13\OR_ABI-L2-ACMC-M6_G16_s20231831331180_e20231831333553_c20231831334509.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\183\22\OR_ABI-L2-ACMC-M6_G16_s20231832236181_e20231832238554_c20231832239432.nc was skipped due to incomplete scan
# Max scans for 184 is 288
# scan D:\GOES_data_CM\2023\184\10\OR_ABI-L2-ACMC-M6_G16_s20231841006182_e20231841008554_c20231841009561.nc was skipped due to incomplete scan
# Max scans for 185 is 288
# Max scans for 186 is 288
# Max scans for 187 is 287
# Max scans for 188 is 288
# scan D:\GOES_data_CM\2023\188\09\OR_ABI-L2-ACMC-M6_G16_s20231880931186_e20231880933559_c20231880934463.nc was skipped due to incomplete scan
# Max scans for 189 is 284
# scan D:\GOES_data_CM\2023\189\19\OR_ABI-L2-ACMC-M6_G16_s20231891941170_e20231891943543_c20231891944557.nc was skipped due to incomplete scan
# Max scans for 190 is 288
# Max scans for 191 is 288
# Max scans for 192 is 288
# scan D:\GOES_data_CM\2023\192\16\OR_ABI-L2-ACMC-M6_G16_s20231921631173_e20231921633546_c20231921634502.nc was skipped due to incomplete scan
# Max scans for 193 is 288
# scan D:\GOES_data_CM\2023\193\04\OR_ABI-L2-ACMC-M6_G16_s20231930436173_e20231930438546_c20231930439489.nc was skipped due to incomplete scan
# Max scans for 194 is 288
# scan D:\GOES_data_CM\2023\194\00\OR_ABI-L2-ACMC-M6_G16_s20231940021174_e20231940023547_c20231940024488.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\194\11\OR_ABI-L2-ACMC-M6_G16_s20231941131174_e20231941133547_c20231941134459.nc was skipped due to incomplete scan
# Max scans for 195 is 288
# scan D:\GOES_data_CM\2023\195\01\OR_ABI-L2-ACMC-M6_G16_s20231950111175_e20231950113548_c20231950114544.nc was skipped due to incomplete scan
# Max scans for 196 is 288
# Max scans for 197 is 288
# Max scans for 198 is 288
# scan D:\GOES_data_CM\2023\198\19\OR_ABI-L2-ACMC-M6_G16_s20231981956178_e20231981958551_c20231982000031.nc was skipped due to incomplete scan
# Max scans for 199 is 287
# scan D:\GOES_data_CM\2023\199\11\OR_ABI-L2-ACMC-M6_G16_s20231991111178_e20231991113551_c20231991114570.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\199\16\OR_ABI-L2-ACMC-M6_G16_s20231991606179_e20231991608552_c20231991609529.nc was skipped due to incomplete scan
# Max scans for 200 is 288
# scan D:\GOES_data_CM\2023\200\06\OR_ABI-L2-ACMC-M6_G16_s20232000621179_e20232000623552_c20232000625478.nc was skipped due to incomplete scan
# Max scans for 201 is 288
# Max scans for 202 is 288
# scan D:\GOES_data_CM\2023\202\02\OR_ABI-L2-ACMC-M6_G16_s20232020231180_e20232020233553_c20232020237293.nc was skipped due to incomplete scan
# Max scans for 203 is 287
# Max scans for 204 is 288
# Max scans for 205 is 288
# Max scans for 206 is 288
# Max scans for 207 is 288
# Max scans for 208 is 288
# Max scans for 209 is 287
# Max scans for 210 is 288
# Max scans for 211 is 288
# Max scans for 212 is 288
# Max scans for 213 is 288
# Max scans for 214 is 288
# Max scans for 215 is 288
# Max scans for 216 is 283
# scan D:\GOES_data_CM\2023\216\19\OR_ABI-L2-ACMC-M6_G16_s20232161906176_e20232161908549_c20232161915451.nc was skipped due to incomplete scan
# Max scans for 217 is 288
# scan D:\GOES_data_CM\2023\217\22\OR_ABI-L2-ACMC-M6_G16_s20232172206170_e20232172208543_c20232172209475.nc was skipped due to incomplete scan
# Max scans for 218 is 288
# Max scans for 219 is 288
# scan D:\GOES_data_CM\2023\219\18\OR_ABI-L2-ACMC-M6_G16_s20232191811171_e20232191813544_c20232191814473.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\219\20\OR_ABI-L2-ACMC-M6_G16_s20232192011171_e20232192013544_c20232192021010.nc was skipped due to incomplete scan
# Max scans for 220 is 287
# Max scans for 221 is 288
# Max scans for 222 is 288
# Max scans for 223 is 288
# Max scans for 224 is 288
# Max scans for 225 is 288
# Max scans for 226 is 287
# Max scans for 227 is 287
# Max scans for 228 is 288
# Max scans for 229 is 288
# scan D:\GOES_data_CM\2023\229\15\OR_ABI-L2-ACMC-M6_G16_s20232291506174_e20232291508547_c20232291510196.nc was skipped due to incomplete scan
# Max scans for 230 is 288
# Max scans for 231 is 288
# scan D:\GOES_data_CM\2023\231\11\OR_ABI-L2-ACMC-M4_G16_s20232311105224_e20232311105224_c20232311112051.nc was skipped due to incomplete scan
# Max scans for 232 is 288
# Max scans for 233 is 288
# scan D:\GOES_data_CM\2023\233\17\OR_ABI-L2-ACMC-M6_G16_s20232331736170_e20232331738543_c20232331739504.nc was skipped due to incomplete scan
# Max scans for 234 is 288
# Max scans for 235 is 287
# Max scans for 236 is 288
# Max scans for 237 is 288
# Max scans for 238 is 288
# scan D:\GOES_data_CM\2023\238\07\OR_ABI-L2-ACMC-M6_G16_s20232380721171_e20232380723544_c20232380724479.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\238\23\OR_ABI-L2-ACMC-M6_G16_s20232382331171_e20232382333544_c20232382336432.nc was skipped due to incomplete scan
# Max scans for 239 is 288
# Max scans for 240 is 288
# scan D:\GOES_data_CM\2023\240\04\OR_ABI-L2-ACMC-M6_G16_s20232400436183_e20232400438544_c20232400439417.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\240\04\OR_ABI-L2-ACMC-M6_G16_s20232400441192_e20232400443544_c20232400444520.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\240\04\OR_ABI-L2-ACMC-M6_G16_s20232400446201_e20232400448544_c20232400449490.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\240\04\OR_ABI-L2-ACMC-M6_G16_s20232400451210_e20232400453544_c20232400454460.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\240\04\OR_ABI-L2-ACMC-M6_G16_s20232400456171_e20232400458544_c20232400459506.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\240\05\OR_ABI-L2-ACMC-M6_G16_s20232400501171_e20232400503544_c20232400504535.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\240\05\OR_ABI-L2-ACMC-M6_G16_s20232400506171_e20232400508544_c20232400509499.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\240\05\OR_ABI-L2-ACMC-M6_G16_s20232400511171_e20232400513544_c20232400514565.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\240\05\OR_ABI-L2-ACMC-M6_G16_s20232400516171_e20232400518544_c20232400519487.nc was skipped due to incomplete scan
# Max scans for 241 is 288
# scan D:\GOES_data_CM\2023\241\04\OR_ABI-L2-ACMC-M6_G16_s20232410436188_e20232410438544_c20232410439485.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\241\04\OR_ABI-L2-ACMC-M6_G16_s20232410441197_e20232410443544_c20232410444516.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\241\04\OR_ABI-L2-ACMC-M6_G16_s20232410446206_e20232410448544_c20232410449561.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\241\04\OR_ABI-L2-ACMC-M6_G16_s20232410451215_e20232410453544_c20232410454515.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\241\04\OR_ABI-L2-ACMC-M6_G16_s20232410456171_e20232410458544_c20232410459569.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\241\05\OR_ABI-L2-ACMC-M6_G16_s20232410501171_e20232410503544_c20232410504480.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\241\05\OR_ABI-L2-ACMC-M6_G16_s20232410506171_e20232410508544_c20232410509475.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\241\05\OR_ABI-L2-ACMC-M6_G16_s20232410511171_e20232410513544_c20232410514509.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023
nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\257\04\OR_ABI-L2-ACMC-M6_G16_s20232570431173_e20232570433546_c20232570434457.nc was skipped due to incomplete scan
# Max scans for 258 is 288
# scan D:\GOES_data_CM\2023\258\04\OR_ABI-L2-ACMC-M6_G16_s20232580421173_e20232580423546_c20232580424399.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\258\04\OR_ABI-L2-ACMC-M6_G16_s20232580426173_e20232580428547_c20232580429467.nc was skipped due to incomplete scan
# Max scans for 259 is 288
# scan D:\GOES_data_CM\2023\259\04\OR_ABI-L2-ACMC-M6_G16_s20232590421173_e20232590423546_c20232590424390.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\259\04\OR_ABI-L2-ACMC-M6_G16_s20232590426174_e20232590428548_c20232590429430.nc was skipped due to incomplete scan
# Max scans for 260 is 288
# scan D:\GOES_data_CM\2023\260\04\OR_ABI-L2-ACMC-M6_G16_s20232600421170_e20232600423543_c20232600424434.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\260\04\OR_ABI-L2-ACMC-M6_G16_s20232600426170_e20232600428543_c20232600429440.nc was skipped due to incomplete scan
# Max scans for 261 is 288
# scan D:\GOES_data_CM\2023\261\04\OR_ABI-L2-ACMC-M6_G16_s20232610421170_e20232610423543_c20232610424401.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\261\04\OR_ABI-L2-ACMC-M6_G16_s20232610426170_e20232610428543_c20232610429395.nc was skipped due to incomplete scan
# Max scans for 262 is 288
# scan D:\GOES_data_CM\2023\262\04\OR_ABI-L2-ACMC-M6_G16_s20232620421171_e20232620423544_c20232620424444.nc was skipped due to incomplete scan
# Max scans for 263 is 288
# scan D:\GOES_data_CM\2023\263\04\OR_ABI-L2-ACMC-M6_G16_s20232630421171_e20232630423544_c20232630424444.nc was skipped due to incomplete scan
# Max scans for 264 is 287
# scan D:\GOES_data_CM\2023\264\04\OR_ABI-L2-ACMC-M6_G16_s20232640421172_e20232640423545_c20232640424412.nc was skipped due to incomplete scan
# Max scans for 265 is 288
# scan D:\GOES_data_CM\2023\265\04\OR_ABI-L2-ACMC-M6_G16_s20232650421172_e20232650423545_c20232650424443.nc was skipped due to incomplete scan
# Max scans for 266 is 288
# Max scans for 267 is 288
# Max scans for 268 is 288
# Max scans for 269 is 287
# scan D:\GOES_data_CM\2023\269\20\OR_ABI-L2-ACMC-M6_G16_s20232692001174_e20232692001174_c20232692006484.nc was skipped due to incomplete scan
# Max scans for 270 is 287
# scan D:\GOES_data_CM\2023\270\11\OR_ABI-L2-ACMC-M6_G16_s20232701126175_e20232701128547_c20232701131140.nc was skipped due to incomplete scan
# Max scans for 271 is 288
# Max scans for 272 is 288
# Max scans for 273 is 288
# Max scans for 274 is 288
# Max scans for 275 is 288
# scan D:\GOES_data_CM\2023\275\16\OR_ABI-L2-ACMC-M6_G16_s20232751606171_e20232751608544_c20232751612294.nc was skipped due to incomplete scan
# Max scans for 276 is 288
# Max scans for 277 is 288
# Max scans for 278 is 288
# Max scans for 279 is 288
# Max scans for 280 is 288
# Max scans for 281 is 288
# Max scans for 282 is 288
# Max scans for 283 is 288
# Max scans for 284 is 288
# scan D:\GOES_data_CM\2023\284\15\OR_ABI-L2-ACMC-M6_G16_s20232841521174_e20232841523547_c20232841524502.nc was skipped due to incomplete scan
# Max scans for 285 is 288
# Max scans for 286 is 287
# Max scans for 287 is 288
# Max scans for 288 is 288
# Max scans for 289 is 288
# Max scans for 290 is 287
# scan D:\GOES_data_CM\2023\290\15\OR_ABI-L2-ACMC-M6_G16_s20232901501171_e20232901503544_c20232901504518.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\290\15\OR_ABI-L2-ACMC-M6_G16_s20232901506171_e20232901508544_c20232901509473.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\290\15\OR_ABI-L2-ACMC-M6_G16_s20232901511171_e20232901513544_c20232901514490.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\290\15\OR_ABI-L2-ACMC-M6_G16_s20232901516171_e20232901518544_c20232901519488.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\290\16\OR_ABI-L2-ACMC-M6_G16_s20232901611171_e20232901613544_c20232901614470.nc was skipped due to incomplete scan
# Max scans for 291 is 278
# Max scans for 292 is 288
# Max scans for 293 is 288
# Max scans for 294 is 288
# Max scans for 295 is 288
# Max scans for 296 is 288
# Max scans for 297 is 288
# Max scans for 298 is 288
# Max scans for 299 is 288
# Max scans for 300 is 288
# Max scans for 301 is 288
# scan D:\GOES_data_CM\2023\301\05\OR_ABI-L2-ACMC-M6_G16_s20233010531176_e20233010533549_c20233010534455.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\301\10\OR_ABI-L2-ACMC-M4_G16_s20233011045224_e20233011045224_c20233011052072.nc was skipped due to incomplete scan
# Max scans for 302 is 288
# Max scans for 303 is 287
# Max scans for 304 is 288
# scan D:\GOES_data_CM\2023\304\12\OR_ABI-L2-ACMC-M6_G16_s20233041226171_e20233041228544_c20233041235264.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\304\12\OR_ABI-L2-ACMC-M6_G16_s20233041251171_e20233041253544_c20233041300422.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\304\12\OR_ABI-L2-ACMC-M6_G16_s20233041256171_e20233041258544_c20233041303569.nc was skipped due to incomplete scan
# Max scans for 305 is 288
# Max scans for 306 is 288
# Max scans for 307 is 288
# scan D:\GOES_data_CM\2023\307\13\OR_ABI-L2-ACMC-M6_G16_s20233071306173_e20233071308546_c20233071309471.nc was skipped due to incomplete scan
# Max scans for 308 is 288
# scan D:\GOES_data_CM\2023\308\03\OR_ABI-L2-ACMC-M6_G16_s20233080306173_e20233080308546_c20233080309443.nc was skipped due to incomplete scan
# Max scans for 309 is 276
# Max scans for 310 is 287
# Max scans for 311 is 288
# Max scans for 312 is 288
# Max scans for 313 is 288
# Max scans for 314 is 288
# Max scans for 315 is 288
# scan D:\GOES_data_CM\2023\315\10\OR_ABI-L2-ACMC-M4_G16_s20233151045224_e20233151045224_c20233151051557.nc was skipped due to incomplete scan
# Max scans for 316 is 288
# Max scans for 317 is 288
# Max scans for 318 is 288
# Max scans for 319 is 288
# Max scans for 320 is 288
# Max scans for 321 is 288
# Max scans for 322 is 288
# Max scans for 323 is 287
# scan D:\GOES_data_CM\2023\323\12\OR_ABI-L2-ACMC-M6_G16_s20233231246174_e20233231248547_c20233231255348.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\323\12\OR_ABI-L2-ACMC-M6_G16_s20233231256174_e20233231258547_c20233231302069.nc was skipped due to incomplete scan
# Max scans for 324 is 288
# Max scans for 325 is 288
# Max scans for 326 is 288
# Max scans for 327 is 288
# Max scans for 328 is 288
# Max scans for 329 is 287
# scan D:\GOES_data_CM\2023\329\05\OR_ABI-L2-ACMC-M6_G16_s20233290516177_e20233290518550_c20233290519487.nc was skipped due to incomplete scan
# Max scans for 330 is 288
# Max scans for 331 is 287
# Max scans for 332 is 288
# scan D:\GOES_data_CM\2023\332\17\OR_ABI-L2-ACMC-M6_G16_s20233321701170_e20233321701170_c20233321709453.nc was skipped due to incomplete scan
# Max scans for 333 is 287
# Max scans for 334 is 288
# Max scans for 335 is 288
# Max scans for 336 is 288
# Max scans for 337 is 288
# Max scans for 338 is 273
# Max scans for 339 is 288
# Max scans for 340 is 288
# Max scans for 341 is 281
# scan D:\GOES_data_CM\2023\341\16\OR_ABI-L2-ACMC-M6_G16_s20233411616174_e20233411618547_c20233411619534.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\341\19\OR_ABI-L2-ACMC-M6_G16_s20233411916174_e20233411918547_c20233411921156.nc was skipped due to incomplete scan
# Max scans for 342 is 288
# Max scans for 343 is 288
# Max scans for 344 is 288
# Max scans for 345 is 287
# Max scans for 346 is 287
# scan D:\GOES_data_CM\2023\346\15\OR_ABI-L2-ACMC-M6_G16_s20233461506170_e20233461508543_c20233461511224.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\346\15\OR_ABI-L2-ACMC-M6_G16_s20233461511170_e20233461513543_c20233461513584.nc was skipped due to incomplete scan
# Max scans for 347 is 288
# Max scans for 348 is 288
# Max scans for 349 is 288
# Max scans for 350 is 166
# scan D:\GOES_data_CM\2023\350\09\OR_ABI-L2-ACMC-M6_G16_s20233500921172_e20233500923545_c20233500930383.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\09\OR_ABI-L2-ACMC-M6_G16_s20233500951172_e20233500953545_c20233501001248.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\10\OR_ABI-L2-ACMC-M6_G16_s20233501021172_e20233501023545_c20233501031240.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\11\OR_ABI-L2-ACMC-M6_G16_s20233501106172_e20233501108545_c20233501116239.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\11\OR_ABI-L2-ACMC-M6_G16_s20233501121172_e20233501123545_c20233501131252.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\11\OR_ABI-L2-ACMC-M6_G16_s20233501126172_e20233501128545_c20233501136217.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\13\OR_ABI-L2-ACMC-M6_G16_s20233501336172_e20233501338545_c20233501346418.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\14\OR_ABI-L2-ACMC-M6_G16_s20233501416172_e20233501418545_c20233501426255.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\14\OR_ABI-L2-ACMC-M6_G16_s20233501421172_e20233501423545_c20233501431333.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\14\OR_ABI-L2-ACMC-M6_G16_s20233501426172_e20233501428545_c20233501436252.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\14\OR_ABI-L2-ACMC-M6_G16_s20233501441172_e20233501443545_c20233501451334.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\14\OR_ABI-L2-ACMC-M6_G16_s20233501446172_e20233501448545_c20233501456253.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\14\OR_ABI-L2-ACMC-M6_G16_s20233501456172_e20233501458545_c20233501506498.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\15\OR_ABI-L2-ACMC-M6_G16_s20233501501172_e20233501503545_c20233501511267.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\15\OR_ABI-L2-ACMC-M6_G16_s20233501506172_e20233501508545_c20233501516375.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\15\OR_ABI-L2-ACMC-M6_G16_s20233501511172_e20233501513545_c20233501521275.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\15\OR_ABI-L2-ACMC-M6_G16_s20233501516172_e20233501518545_c20233501526354.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\15\OR_ABI-L2-ACMC-M6_G16_s20233501521172_e20233501523545_c20233501531263.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\15\OR_ABI-L2-ACMC-M6_G16_s20233501526172_e20233501528545_c20233501536356.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\15\OR_ABI-L2-ACMC-M6_G16_s20233501531172_e20233501533545_c20233501541024.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\15\OR_ABI-L2-ACMC-M6_G16_s20233501536172_e20233501538545_c20233501546398.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\350\15\OR_ABI-L2-ACMC-M6_G16_s20233501541172_e20233501543545_c20233501551022.nc was skipped due to incomplete scan
# Max scans for 351 is 288
# Max scans for 352 is 288
# scan D:\GOES_data_CM\2023\352\16\OR_ABI-L2-ACMC-M6_G16_s20233521656173_e20233521658546_c20233521704466.nc was skipped due to incomplete scan
# Max scans for 353 is 288
# Max scans for 354 is 288
# Max scans for 355 is 286
# Max scans for 356 is 288
# Max scans for 357 is 288
# Max scans for 358 is 288
# Max scans for 359 is 288
# Max scans for 360 is 288
# Max scans for 361 is 288
# scan D:\GOES_data_CM\2023\361\05\OR_ABI-L2-ACMC-M6_G16_s20233610556171_e20233610558543_c20233610601188.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\361\07\OR_ABI-L2-ACMC-M6_G16_s20233610706171_e20233610708543_c20233610709567.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\361\19\OR_ABI-L2-ACMC-M6_G16_s20233611946171_e20233611948544_c20233611951122.nc was skipped due to incomplete scan
# Max scans for 362 is 288
# scan D:\GOES_data_CM\2023\362\13\OR_ABI-L2-ACMC-M6_G16_s20233621341171_e20233621343544_c20233621349477.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\362\13\OR_ABI-L2-ACMC-M6_G16_s20233621346171_e20233621348544_c20233621354504.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\362\13\OR_ABI-L2-ACMC-M6_G16_s20233621351171_e20233621353544_c20233621359479.nc was skipped due to incomplete scan
# scan D:\GOES_data_CM\2023\362\13\OR_ABI-L2-ACMC-M6_G16_s20233621356171_e20233621358544_c20233621404072.nc was skipped due to incomplete scan
# Max scans for 363 is 288
# Max scans for 364 is 288
# Max scans for 365 is 286

# %%
# print(str(np.count_nonzero(np.isnan(ds.BCM.values))))
# len(coverage_frequency)
# Out:
# 1500

# %%
# Make yearly coverage nc
YTC = xr.Dataset({'Yearly_Total_Coverage': (('y', 'x'), yearly_total_coverage)},
                        coords={'x': ds.x.values * sat_height, 'y': ds.y.values * sat_height})

YTC.rio.write_crs(cc.to_string(), inplace=True)

year_coverage_final = YTC.rio.reproject("EPSG:3857")

# Save the aggregated data to a new NetCDF file
year_coverage_final.to_netcdf('D:/GOES_YEARLY_COVERAGE/2023.nc') # aggregated coverage data

# %%
nc_dir = 'D:/GOES_CF_NCs/2023'

# %%
# Read all the nc file paths
nc_paths = glob.glob(os.path.join(nc_dir, '*.nc'))

# Count the .nc files and store as a variable

def count_files_with_extension(folder_path, extension):
    # Get the list of files in the specified folder
    files = os.listdir(folder_path)

    # Filter files with the specified extension
    nc_files = [file for file in files if file.endswith(extension)]

    # Count the number of filtered files
    count = len(nc_files)

    return count

# Define the extension type

extension = '.nc'

# Call the function to count files with the specified extension
file_count = count_files_with_extension(nc_dir, extension)

print(f'The number of files with {extension} extension in {nc_dir} is: {file_count}')

# Stacking the images
img_stack = np.zeros(shape=(file_count, 1408, 2553))

for i, nc_path in enumerate(nc_paths):
    src = rasterio.open(nc_path)
    img = src.read()
    img_stack[i, :, :] = img
    src.close()
    
    
#open the bil file
src = rasterio.open(nc_paths[0])

#Read metadata
profile = src.profile
profile

#Make a composite raster of the temp data
profile.update(
    driver='GTiff',
    count=file_count)

out_path = r'D:/GOES_CF_RASTERS/2023_Cloud_Frequency.tif'

with rasterio.open(out_path, 'w', **profile) as dst:
    dst.write(img_stack)
    
src.close()

# Time to run ~17 minutes
# Out:
# The number of files with .nc extension in D:/GOES_CF_NCs/2023 is: 365
